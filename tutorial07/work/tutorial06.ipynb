# %%
pip install pandas pyarrow fsspec s3fs
# Out:
# Requirement already satisfied: pandas in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: pyarrow in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (19.0.0)
# Requirement already satisfied: fsspec in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (2025.3.2)
# Requirement already satisfied: s3fs in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (2025.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from s3fs) (2.22.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from s3fs) (3.11.18)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.12.0)
# Collecting botocore<1.37.4,>=1.37.2 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Using cached botocore-1.37.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (6.4.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.6.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.20.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from botocore<1.37.4,>=1.37.2->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna>=2.0 in c:\users\natth\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.10)
# Using cached botocore-1.37.3-py3-none-any.whl (13.3 MB)
# Installing collected packages: botocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.38.10
#     Uninstalling botocore-1.38.10:
#       Successfully uninstalled botocore-1.38.10
# Successfully installed botocore-1.37.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.38.10 requires botocore<1.39.0,>=1.38.10, but you have botocore 1.37.3 which is incompatible.
# s3transfer 0.12.0 requires botocore<2.0a.0,>=1.37.4, but you have botocore 1.37.3 which is incompatible.

# %%
import requests
import pandas as pd
from datetime import datetime
import pytz

# API endpoint and parameters
WEATHER_ENDPOINT = "https://api.openweathermap.org/data/2.5/weather"
API_KEY = "a35eabb640026f7b88461e8d99ca6532"  # Replace with your actual API key


provinces = {
    "Pathum Thani":{
        "lat": 14.0134,
        "lon": 100.5304
    },
    "Bangkok":{
            "lat": 13.7367,
            "lon": 100.5232
    },
    "Chiang Mai":{
        "lat": 18.7883,
        "lon": 98.9853
    },
    "Phuket":{
        "lat": 7.9519,
        "lon": 98.3381
    }
}
# Function to fetch and process weather data
def get_weather_data(province='Pathum Thani'):
    
    params = {
        "lat": provinces[province]['lat'],
        "lon": provinces[province]['lon'],
        "appid": API_KEY,
        "units": "metric"
    }
    try:
        # Make API request
        response = requests.get(WEATHER_ENDPOINT, params=params)
        response.raise_for_status()  # Raise an exception for bad status codes
        data = response.json()
        
        # Convert timestamp to datetime
        # created_at = datetime.fromtimestamp(data['dt'])

        dt = datetime.now()
        thai_tz = pytz.timezone('Asia/Bangkok')
        created_at = dt.replace(tzinfo=thai_tz)


        timestamp = datetime.now()
        
        # Create dictionary with required fields
        weather_dict = {
            'timestamp': timestamp,
            'year': timestamp.year,
            'month': timestamp.month,
            'day': timestamp.day,
            'hour': timestamp.hour,
            'minute': timestamp.minute,
            'created_at': created_at,
            'requested_province':province,
            'location': data['name'],
            'weather_main': data['weather'][0]['main'],
            'weather_description': data['weather'][0]['description'],
            'main.temp': data['main']['temp']
        }
        
        # Create DataFrame
        # df = pd.DataFrame([weather_dict])
        
        # return df
        return weather_dict
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
    except KeyError as e:
        print(f"Error processing data: Missing key {e}")
        return None

# %%
df=pd.DataFrame([get_weather_data(p) for p in list(provinces.keys())])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            4 non-null      datetime64[ns]
#  1   year                 4 non-null      int64
#  2   month                4 non-null      int64
#  3   day                  4 non-null      int64
#  4   hour                 4 non-null      int64
#  5   minute               4 non-null      int64
#  6   created_at           4 non-null      datetime64[ns, Asia/Bangkok]
#  7   requested_province   4 non-null      object
#  8   location             4 non-null      object
#  9   weather_main         4 non-null      object
#  10  weather_description  4 non-null      object
#  11  main.temp            4 non-null      float64
# dtypes: datetime64[ns, Asia/Bangkok](1), datetime64[ns](1), float64(1), int64(5), object(4)
# memory usage: 516.0+ bytes
#                    timestamp  year  month  day  hour  minute  \
# 0 2025-05-07 17:15:11.939157  2025      5    7    17      15
# 1 2025-05-07 17:15:12.139029  2025      5    7    17      15
# 2 2025-05-07 17:15:12.349134  2025      5    7    17      15
# 3 2025-05-07 17:15:12.575070  2025      5    7    17      15
#
#                         created_at requested_province      location  \
# 0 2025-05-07 17:33:11.939146+07:00       Pathum Thani  Pathum Thani
# 1 2025-05-07 17:33:12.139020+07:00            Bangkok    Pathum Wan
# 2 2025-05-07 17:33:12.349126+07:00         Chiang Mai    Chiang Mai
# 3 2025-05-07 17:33:12.575061+07:00             Phuket         Kathu
#
#   weather_main weather_description  main.temp
# 0       Clouds    scattered clouds      33.36
# 1       Clouds     overcast clouds      33.69
# 2       Clouds    scattered clouds      35.37
# 3       Clouds    scattered clouds      26.92

# %%
dt = datetime.now()
thai_tz = pytz.timezone('Asia/Bangkok')
dt = dt.replace(tzinfo=thai_tz)
print(dt)
# Out:
# 2025-05-07 17:15:16.733862+06:42

# %%
import pandas as pd

# lakeFS credentials from your docker-compose.yml
ACCESS_KEY = "access_key"
SECRET_KEY = "secret_key"

# lakeFS endpoint (running locally)
lakefs_endpoint = "http://lakefs-dev:8000/"

# lakeFS repository, branch, and file path
repo = "weather"
branch = "main"
path = "weather.parquet"

# Construct the full lakeFS S3-compatible path
lakefs_s3_path = f"s3a://{repo}/{branch}/{path}"

# Configure storage_options for lakeFS (S3-compatible)
storage_options = {
    "key": ACCESS_KEY,
    "secret": SECRET_KEY,
    "client_kwargs": {
        "endpoint_url": lakefs_endpoint
    }
}

# %%
df.to_parquet(
    lakefs_s3_path,
    storage_options=storage_options,
    partition_cols=['year','month','day','hour'],
    
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiohttp\connector.py:1357, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1353 try:
#    1354     # Cancelling this lookup should not cancel the underlying lookup
#    1355     #  or else the cancel event will get broadcast to all the waiters
#    1356     #  across all connections.
# -> 1357     hosts = await self._resolve_host(host, port, traces=traces)
#    1358 except OSError as exc:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiohttp\connector.py:995, in TCPConnector._resolve_host(self, host, port, traces)
#     994 try:
# --> 995     return await asyncio.shield(resolved_host_task)
#     996 except asyncio.CancelledError:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiohttp\connector.py:1026, in TCPConnector._resolve_host_with_throttle(self, key, host, port, futures, traces)
#    1024         await trace.send_dns_resolvehost_start(host)
# -> 1026 addrs = await self._resolver.resolve(host, port, family=self._family)
#    1027 if traces:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiohttp\resolver.py:39, in ThreadedResolver.resolve(self, host, port, family)
#      36 async def resolve(
#      37     self, host: str, port: int = 0, family: socket.AddressFamily = socket.AF_INET
#      38 ) -> List[ResolveResult]:
# ---> 39     infos = await self._loop.getaddrinfo(
#      40         host,
#      41         port,
#      42         type=socket.SOCK_STREAM,
#      43         family=family,
#      44         flags=_AI_ADDRCONFIG,
#      45     )
#      47     hosts: List[ResolveResult] = []
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py:933, in BaseEventLoop.getaddrinfo(self, host, port, family, type, proto, flags)
#     931     getaddr_func = socket.getaddrinfo
# --> 933 return await self.run_in_executor(
#     934     None, getaddr_func, host, port, family, type, proto, flags)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorDNSError                   Traceback (most recent call last)
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\httpsession.py:222, in AIOHTTPSession.send(self, request)
#     221 session = await self._get_session(proxy_url)
# --> 222 response = await session.request(
#     223     request.method,
#     224     url=url,
#     225     chunked=self._chunked(headers_),
#     226     headers=headers_,
#     227     data=data,
#     228     proxy=proxy_url,
#     229     proxy_headers=proxy_headers,
#     230 )
#     232 # botocore converts keys to str, so make sure that they are in
#     233 # the expected case. See detailed discussion here:
#     234 # https://github.com/aio-libs/aiobotocore/pull/116
#     235 # aiohttp's CIMultiDict camel cases the headers :(
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiohttp\client.py:703, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     702 try:
# --> 703     conn = await self._connector.connect(
#     704         req, traces=traces, timeout=real_timeout
#     705     )
#     706 except asyncio.TimeoutError as exc:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiohttp\connector.py:548, in BaseConnector.connect(self, req, traces, timeout)
#     547         await trace.send_connection_create_start()
# --> 548 proto = await self._create_connection(req, traces, timeout)
#     549 if traces:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiohttp\connector.py:1056, in TCPConnector._create_connection(self, req, traces, timeout)
#    1055 else:
# -> 1056     _, proto = await self._create_direct_connection(req, traces, timeout)
#    1058 return proto
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiohttp\connector.py:1363, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1361     # in case of proxy it is not ClientProxyConnectionError
#    1362     # it is problem of resolving proxy ip itself
# -> 1363     raise ClientConnectorDNSError(req.connection_key, exc) from exc
#    1365 last_exc: Optional[Exception] = None
#
# ClientConnectorDNSError: Cannot connect to host lakefs-dev:8000 ssl:default [getaddrinfo failed]
#
# During handling of the above exception, another exception occurred:
#
# EndpointConnectionError                   Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.to_parquet(
#       2     lakefs_s3_path,
#       3     storage_options=storage_options,
#       4     partition_cols=['year','month','day','hour'],
#       5
#       6 )
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parquet.py:480, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 480 impl.write(
#     481     df,
#     482     path_or_buf,
#     483     compression=compression,
#     484     index=index,
#     485     partition_cols=partition_cols,
#     486     storage_options=storage_options,
#     487     filesystem=filesystem,
#     488     **kwargs,
#     489 )
#     491 if path is None:
#     492     assert isinstance(path_or_buf, io.BytesIO)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parquet.py:218, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     215 try:
#     216     if partition_cols is not None:
#     217         # writes to multiple files under the given path
# --> 218         self.api.parquet.write_to_dataset(
#     219             table,
#     220             path_or_handle,
#     221             compression=compression,
#     222             partition_cols=partition_cols,
#     223             filesystem=filesystem,
#     224             **kwargs,
#     225         )
#     226     else:
#     227         # write to single output file
#     228         self.api.parquet.write_table(
#     229             table,
#     230             path_or_handle,
#    (...)    233             **kwargs,
#     234         )
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyarrow\parquet\core.py:2172, in write_to_dataset(table, root_path, partition_cols, filesystem, use_legacy_dataset, schema, partitioning, basename_template, use_threads, file_visitor, existing_data_behavior, **kwargs)
#    2169 if existing_data_behavior is None:
#    2170     existing_data_behavior = 'overwrite_or_ignore'
# -> 2172 ds.write_dataset(
#    2173     table, root_path, filesystem=filesystem,
#    2174     format=parquet_format, file_options=write_options, schema=schema,
#    2175     partitioning=partitioning, use_threads=use_threads,
#    2176     file_visitor=file_visitor,
#    2177     basename_template=basename_template,
#    2178     existing_data_behavior=existing_data_behavior,
#    2179     **write_dataset_kwargs)
#    2180 return
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyarrow\dataset.py:1034, in write_dataset(data, base_dir, basename_template, format, partitioning, partitioning_flavor, schema, filesystem, file_options, use_threads, max_partitions, max_open_files, max_rows_per_file, min_rows_per_group, max_rows_per_group, file_visitor, existing_data_behavior, create_dir)
#    1031         raise ValueError("Cannot specify a schema when writing a Scanner")
#    1032     scanner = data
# -> 1034 _filesystemdataset_write(
#    1035     scanner, base_dir, basename_template, filesystem, partitioning,
#    1036     file_options, max_partitions, file_visitor, existing_data_behavior,
#    1037     max_open_files, max_rows_per_file,
#    1038     min_rows_per_group, max_rows_per_group, create_dir
#    1039 )
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyarrow\_dataset.pyx:4071, in pyarrow._dataset._filesystemdataset_write()
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyarrow\error.pxi:89, in pyarrow.lib.check_status()
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyarrow\_fs.pyx:1526, in pyarrow._fs._cb_create_dir()
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyarrow\fs.py:361, in FSSpecHandler.create_dir(self, path, recursive)
#     358 def create_dir(self, path, recursive):
#     359     # mkdir also raises FileNotFoundError when base directory is not found
#     360     try:
# --> 361         self.fs.mkdir(path, create_parents=recursive)
#     362     except FileExistsError:
#     363         pass
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\fsspec\asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:954, in S3FileSystem._mkdir(self, path, acl, create_parents, **kwargs)
#     950 if region_name:
#     951     params["CreateBucketConfiguration"] = {
#     952         "LocationConstraint": region_name
#     953     }
# --> 954 await self._call_s3("create_bucket", **params)
#     955 self.invalidate_cache("")
#     956 self.invalidate_cache(bucket)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:371, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     369 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     370 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 371 return await _error_wrapper(
#     372     method, kwargs=additional_kwargs, retries=self.retries
#     373 )
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:146, in _error_wrapper(func, args, kwargs, retries)
#     144         err = e
#     145 err = translate_boto_error(err)
# --> 146 raise err
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\s3fs\core.py:114, in _error_wrapper(func, args, kwargs, retries)
#     112 for i in range(retries):
#     113     try:
# --> 114         return await func(*args, **kwargs)
#     115     except S3_RETRYABLE_ERRORS as e:
#     116         err = e
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\client.py:394, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     390     maybe_compress_request(
#     391         self.meta.config, request_dict, operation_model
#     392     )
#     393     apply_request_checksum(request_dict)
# --> 394     http, parsed_response = await self._make_request(
#     395         operation_model, request_dict, request_context
#     396     )
#     398 await self.meta.events.emit(
#     399     f'after-call.{service_id}.{operation_name}',
#     400     http_response=http,
#    (...)    403     context=request_context,
#     404 )
#     406 if http.status_code >= 300:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\client.py:420, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     416 async def _make_request(
#     417     self, operation_model, request_dict, request_context
#     418 ):
#     419     try:
# --> 420         return await self._endpoint.make_request(
#     421             operation_model, request_dict
#     422         )
#     423     except Exception as e:
#     424         await self.meta.events.emit(
#     425             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#     426             exception=e,
#     427             context=request_context,
#     428         )
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\endpoint.py:113, in AioEndpoint._send_request(self, request_dict, operation_model)
#     109 request = await self.create_request(request_dict, operation_model)
#     110 success_response, exception = await self._get_response(
#     111     request, operation_model, context
#     112 )
# --> 113 while await self._needs_retry(
#     114     attempts,
#     115     operation_model,
#     116     request_dict,
#     117     success_response,
#     118     exception,
#     119 ):
#     120     attempts += 1
#     121     self._update_retries_context(context, attempts, success_response)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\endpoint.py:273, in AioEndpoint._needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     271 service_id = operation_model.service_model.service_id.hyphenize()
#     272 event_name = f"needs-retry.{service_id}.{operation_model.name}"
# --> 273 responses = await self._event_emitter.emit(
#     274     event_name,
#     275     response=response,
#     276     endpoint=self,
#     277     operation=operation_model,
#     278     attempts=attempts,
#     279     caught_exception=caught_exception,
#     280     request_dict=request_dict,
#     281 )
#     282 handler_response = first_non_none_response(responses)
#     283 if handler_response is None:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\hooks.py:68, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      65 logger.debug('Event %s: calling handler %s', event_name, handler)
#      67 # Await the handler if its a coroutine.
# ---> 68 response = await resolve_awaitable(handler(**kwargs))
#      69 responses.append((handler, response))
#      70 if stop_on_response and response is not None:
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\retryhandler.py:107, in AioRetryHandler._call(self, attempts, response, caught_exception, **kwargs)
#     104     retries_context = kwargs['request_dict']['context'].get('retries')
#     105     checker_kwargs.update({'retries_context': retries_context})
# --> 107 if await resolve_awaitable(self._checker(**checker_kwargs)):
#     108     result = self._action(attempts=attempts)
#     109     logger.debug("Retry needed, action of: %s", result)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\retryhandler.py:126, in AioMaxAttemptsDecorator._call(self, attempt_number, response, caught_exception, retries_context)
#     121 if retries_context:
#     122     retries_context['max'] = max(
#     123         retries_context.get('max', 0), self._max_attempts
#     124     )
# --> 126 should_retry = await self._should_retry(
#     127     attempt_number, response, caught_exception
#     128 )
#     129 if should_retry:
#     130     if attempt_number >= self._max_attempts:
#     131         # explicitly set MaxAttemptsReached
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\retryhandler.py:165, in AioMaxAttemptsDecorator._should_retry(self, attempt_number, response, caught_exception)
#     161         return True
#     162 else:
#     163     # If we've exceeded the max attempts we just let the exception
#     164     # propagate if one has occurred.
# --> 165     return await resolve_awaitable(
#     166         self._checker(attempt_number, response, caught_exception)
#     167     )
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\retryhandler.py:174, in AioMultiChecker._call(self, attempt_number, response, caught_exception)
#     171 async def _call(self, attempt_number, response, caught_exception):
#     172     for checker in self._checkers:
#     173         checker_response = await resolve_awaitable(
# --> 174             checker(attempt_number, response, caught_exception)
#     175         )
#     176         if checker_response:
#     177             return checker_response
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\botocore\retryhandler.py:247, in BaseChecker.__call__(self, attempt_number, response, caught_exception)
#     245     return self._check_response(attempt_number, response)
#     246 elif caught_exception is not None:
# --> 247     return self._check_caught_exception(
#     248         attempt_number, caught_exception
#     249     )
#     250 else:
#     251     raise ValueError("Both response and caught_exception are None.")
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\botocore\retryhandler.py:416, in ExceptionRaiser._check_caught_exception(self, attempt_number, caught_exception)
#     408 def _check_caught_exception(self, attempt_number, caught_exception):
#     409     # This is implementation specific, but this class is useful by
#     410     # coordinating with the MaxAttemptsDecorator.
#    (...)    414     # the MaxAttemptsDecorator is not interested in retrying the exception
#     415     # then this exception just propagates out past the retry code.
# --> 416     raise caught_exception
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\endpoint.py:194, in AioEndpoint._do_get_response(self, request, operation_model, context)
#     192     http_response = first_non_none_response(responses)
#     193     if http_response is None:
# --> 194         http_response = await self._send(request)
#     195 except HTTPClientError as e:
#     196     return (None, e)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\endpoint.py:296, in AioEndpoint._send(self, request)
#     295 async def _send(self, request):
# --> 296     return await self.http_session.send(request)
#
# File c:\Users\natth\AppData\Local\Programs\Python\Python313\Lib\site-packages\aiobotocore\httpsession.py:276, in AIOHTTPSession.send(self, request)
#     270         raise ReadTimeoutError(endpoint_url=request.url, error=e)
#     271 except (
#     272     ClientConnectorError,
#     273     ClientConnectionError,
#     274     socket.gaierror,
#     275 ) as e:
# --> 276     raise EndpointConnectionError(endpoint_url=request.url, error=e)
#     277 except asyncio.TimeoutError as e:
#     278     raise ReadTimeoutError(endpoint_url=request.url, error=e)
#
# EndpointConnectionError: Could not connect to the endpoint URL: "http://lakefs-dev:8000/weather"

# %% [markdown]
# # test read parquet files

# %%
path_all_partition = 's3a://weather3/main/weather.parquet'

df2=pd.read_parquet(    
    path=path_all_partition,
    storage_options=storage_options
)
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            4 non-null      datetime64[ns]
#  1   minute               4 non-null      int64
#  2   created_at           4 non-null      datetime64[ns]
#  3   requested_province   4 non-null      object
#  4   location             4 non-null      object
#  5   weather_main         4 non-null      object
#  6   weather_description  4 non-null      object
#  7   main.temp            4 non-null      float64
#  8   year                 4 non-null      category
#  9   month                4 non-null      category
#  10  day                  4 non-null      category
#  11  hour                 4 non-null      category
# dtypes: category(4), datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 788.0+ bytes
#                    timestamp  minute          created_at requested_province  \
# 0 2025-04-10 07:47:13.822721      47 2025-04-10 07:47:13       Pathum Thani
# 1 2025-04-10 07:47:14.092639      47 2025-04-10 07:47:14            Bangkok
# 2 2025-04-10 07:47:14.366322      47 2025-04-10 07:45:25         Chiang Mai
# 3 2025-04-10 07:47:14.637560      47 2025-04-10 07:47:14             Phuket
#
#        location weather_main weather_description  main.temp  year month day  \
# 0  Pathum Thani       Clouds     overcast clouds      34.99  2025     4  10
# 1    Pathum Wan       Clouds     overcast clouds      34.88  2025     4  10
# 2    Chiang Mai       Clouds          few clouds      37.10  2025     4  10
# 3         Kathu       Clouds          few clouds      27.92  2025     4  10
#
#   hour
# 0    7
# 1    7
# 2    7
# 3    7

# %%
path_single_partition = 's3a://weather3/main/weather.parquet/year=2025/month=4/day=10/hour=7/70cf855c5c5e4659ae01aba885c731c3-0.parquet'

df2=pd.read_parquet(    
    path=path_single_partition,
    storage_options=storage_options,
)
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            4 non-null      datetime64[ns]
#  1   minute               4 non-null      int64
#  2   created_at           4 non-null      datetime64[ns]
#  3   requested_province   4 non-null      object
#  4   location             4 non-null      object
#  5   weather_main         4 non-null      object
#  6   weather_description  4 non-null      object
#  7   main.temp            4 non-null      float64
#  8   year                 4 non-null      category
#  9   month                4 non-null      category
#  10  day                  4 non-null      category
#  11  hour                 4 non-null      category
# dtypes: category(4), datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 788.0+ bytes
#                    timestamp  minute          created_at requested_province  \
# 0 2025-04-10 07:47:13.822721      47 2025-04-10 07:47:13       Pathum Thani
# 1 2025-04-10 07:47:14.092639      47 2025-04-10 07:47:14            Bangkok
# 2 2025-04-10 07:47:14.366322      47 2025-04-10 07:45:25         Chiang Mai
# 3 2025-04-10 07:47:14.637560      47 2025-04-10 07:47:14             Phuket
#
#        location weather_main weather_description  main.temp  year month day  \
# 0  Pathum Thani       Clouds     overcast clouds      34.99  2025     4  10
# 1    Pathum Wan       Clouds     overcast clouds      34.88  2025     4  10
# 2    Chiang Mai       Clouds          few clouds      37.10  2025     4  10
# 3         Kathu       Clouds          few clouds      27.92  2025     4  10
#
#   hour
# 0    7
# 1    7
# 2    7
# 3    7

# %%
print(dt)
# Out:
# 2025-04-10 07:50:44.311326+06:42

# %% [markdown]
# # Test Duck and Dask

# %%
# pip install duckdb
import duckdb
import pandas as pd

# Connect to an in-memory DuckDB instance.
con = duckdb.connect(database=':memory:')

storage_options = {
    "key": ACCESS_KEY,
    "secret": SECRET_KEY,
    "client_kwargs": {
        "endpoint_url": lakefs_endpoint
    }
}

# Use DuckDB's read_parquet() function to read the dataset.
# Assume the dataset is stored in the directory "output_parquet_dataset" with hive partitions:
# output_parquet_dataset/year=2025/month=02/day=17/...
query = """
INSTALL httpfs;
LOAD httpfs;

SET s3_endpoint='lakefs-dev:8000';
SET s3_access_key_id='access_key'; 
SET s3_secret_access_key='secret_key'; 
SET s3_url_style='path';
SET s3_use_ssl=false;

SELECT *
FROM read_parquet('s3a://weather3/main/weather.parquet')
"""

df_duck = con.execute(query).df()

print("DuckDB Parquet Query Result:")
df_duck.info()
df_duck.head(20)
# Out:
# ---------------------------------------------------------------------------
# HTTPException                             Traceback (most recent call last)
# Cell In[88], line 32
#      15 # Use DuckDB's read_parquet() function to read the dataset.
#      16 # Assume the dataset is stored in the directory "output_parquet_dataset" with hive partitions:
#      17 # output_parquet_dataset/year=2025/month=02/day=17/...
#      18 query = """
#      19 INSTALL httpfs;
#      20 LOAD httpfs;
#    (...)
#      29 FROM read_parquet('s3a://weather3/main/weather.parquet')
#      30 """
# ---> 32 df_duck = con.execute(query).df()
#      34 print("DuckDB Parquet Query Result:")
#      35 df_duck.info()
#
# HTTPException: HTTP Error: Unable to connect to URL "http://lakefs-dev:8000/weather3/main/weather.parquet": 404 (Not Found).

# %%
# pip install dask
import dask.dataframe as dd
df2 = dd.read_parquet(
    path=path_all_partition,
    storage_options=storage_options,
    dtype_backend='pyarrow'
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/dask/backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/dask_expr/_collection.py:5376, in read_parquet(path, columns, filters, categories, index, storage_options, dtype_backend, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, blocksize, aggregate_files, parquet_file_extension, filesystem, engine, arrow_to_pandas, **kwargs)
#    5357     return new_collection(
#    5358         ReadParquetPyarrowFS(
#    5359             path,
#    (...)
#    5372         )
#    5373     )
#    5375 return new_collection(
# -> 5376     ReadParquetFSSpec(
#    5377         path,
#    5378         columns=_convert_to_list(columns),
#    5379         filters=filters,
#    5380         categories=categories,
#    5381         index=index,
#    5382         storage_options=storage_options,
#    5383         calculate_divisions=calculate_divisions,
#    5384         ignore_metadata_file=ignore_metadata_file,
#    5385         metadata_task_size=metadata_task_size,
#    5386         split_row_groups=split_row_groups,
#    5387         blocksize=blocksize,
#    5388         aggregate_files=aggregate_files,
#    5389         parquet_file_extension=parquet_file_extension,
#    5390         filesystem=filesystem,
#    5391         engine=_set_parquet_engine(engine),
#    5392         kwargs=kwargs,
#    5393         _series=isinstance(columns, str),
#    5394     )
#    5395 )
#
# File /opt/conda/lib/python3.11/site-packages/dask/_expr.py:63, in Expr.__new__(cls, _determ_token, *args, **kwargs)
#      62 inst.operands = [_unpack_collections(o) for o in operands]
# ---> 63 _name = inst._name
#      64 if _name in Expr._instances:
#
# File /opt/conda/lib/python3.11/functools.py:1001, in cached_property.__get__(self, instance, owner)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/dask_expr/io/parquet.py:791, in ReadParquet._name(self)
#     789 @cached_property
#     790 def _name(self):
# --> 791     return self._funcname + "-" + self.deterministic_token
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/dask_expr/io/parquet.py:785, in ReadParquet.deterministic_token(self)
#     782 if not self._determ_token:
#     783     # TODO: Is there an actual need to overwrite this?
#     784     self._determ_token = _tokenize_deterministic(
# --> 785         funcname(type(self)), self.checksum, *self.operands[:-1]
#     786     )
#     787 return self._determ_token
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/dask_expr/io/parquet.py:795, in ReadParquet.checksum(self)
#     793 @property
#     794 def checksum(self):
# --> 795     return self._dataset_info["checksum"]
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/dask_expr/io/parquet.py:1399, in ReadParquetFSSpec._dataset_info(self)
#    1398 # Infer meta, accounting for index and columns arguments.
# -> 1399 meta = self.engine._create_dd_meta(dataset_info)
#    1400 index = dataset_info["index"]
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/io/parquet/arrow.py:1146, in ArrowDatasetEngine._create_dd_meta(cls, dataset_info)
#    1145 dtype_backend = dataset_info["kwargs"]["dtype_backend"]
# -> 1146 meta = cls._arrow_table_to_pandas(
#    1147     schema.empty_table(),
#    1148     categories,
#    1149     arrow_to_pandas=arrow_to_pandas,
#    1150     dtype_backend=dtype_backend,
#    1151     convert_string=convert_string,
#    1152 )
#    1153 index_names = list(meta.index.names)
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/io/parquet/arrow.py:1800, in ArrowDatasetEngine._arrow_table_to_pandas(cls, arrow_table, categories, dtype_backend, convert_string, **kwargs)
#    1798 _kwargs.update({"use_threads": False, "ignore_metadata": False})
# -> 1800 types_mapper = cls._determine_type_mapper(
#    1801     dtype_backend=dtype_backend,
#    1802     convert_string=convert_string,
#    1803     **kwargs,
#    1804 )
#    1805 if types_mapper is not None:
#
# File /opt/conda/lib/python3.11/site-packages/dask/dataframe/io/parquet/arrow.py:1759, in ArrowDatasetEngine._determine_type_mapper(cls, dtype_backend, convert_string, **kwargs)
#    1758 if convert_string:
# -> 1759     type_mappers.append({pa.string(): pd.StringDtype("pyarrow")}.get)
#    1760     if PANDAS_GE_220:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/arrays/string_.py:131, in StringDtype.__init__(self, storage)
#     130 if storage in ("pyarrow", "pyarrow_numpy") and pa_version_under10p1:
# --> 131     raise ImportError(
#     132         "pyarrow>=10.0.1 is required for PyArrow backed StringArray."
#     133     )
#     134 self.storage = storage
#
# ImportError: pyarrow>=10.0.1 is required for PyArrow backed StringArray.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[89], line 2
#       1 import dask.dataframe as dd
# ----> 2 df2 = dd.read_parquet(
#       3     path=path_all_partition,
#       4     storage_options=storage_options,
#       5     dtype_backend='pyarrow'
#       6 )
#
# File /opt/conda/lib/python3.11/site-packages/dask/backends.py:151, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     149     raise e
#     150 else:
# --> 151     raise exc from e
#
# ImportError: An error occurred while calling the read_parquet method registered to the pandas backend.
# Original Message: pyarrow>=10.0.1 is required for PyArrow backed StringArray.
